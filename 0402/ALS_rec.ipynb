# %%
import numpy as np
import scipy
import implicit

print(np.__version__)
print(scipy.__version__)
print(implicit.__version__)
# Out:
# 1.21.4
# 1.7.1
# 0.4.8

# %%
import os
import pandas as pd

rating_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/ratings.dat'
ratings_cols = ['user_id', 'movie_id', 'ratings', 'timestamp']
ratings = pd.read_csv(rating_file_path, sep='::', names=ratings_cols, engine='python', encoding = "ISO-8859-1")
orginal_data_size = len(ratings)
ratings.head()
# Out:
#    user_id  movie_id  ratings  timestamp
# 0        1      1193        5  978300760
# 1        1       661        3  978302109
# 2        1       914        3  978301968
# 3        1      3408        4  978300275
# 4        1      2355        5  978824291

# %%
#timestamp 제거
ratings=ratings.drop('timestamp',axis=1)
ratings.head()
# Out:
#    user_id  movie_id  ratings
# 0        1      1193        5
# 1        1       661        3
# 2        1       914        3
# 3        1      3408        4
# 4        1      2355        5

# %%
# 3점 이상만 남깁니다.
ratings = ratings[ratings['ratings']>=3]
filtered_data_size = len(ratings)

print(f'orginal_data_size: {orginal_data_size}, filtered_data_size: {filtered_data_size}')
print(f'Ratio of Remaining Data is {filtered_data_size / orginal_data_size:.2%}')
# Out:
# orginal_data_size: 1000209, filtered_data_size: 836478
# Ratio of Remaining Data is 83.63%

# %%
# 영화 제목을 보기 위해 메타 데이터를 읽어옵니다.
movie_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/movies.dat'
cols = ['movie_id', 'title', 'genre'] 
movies = pd.read_csv(movie_file_path, sep='::', names=cols, engine='python', encoding='ISO-8859-1')
movies.head()
# Out:
#    movie_id                               title                         genre
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
movies['genre'] = movies['genre'].str.lower()
movies['title'] = movies['title'].str.lower()
movies.head(10)
# Out:
#    movie_id                               title                         genre
# 0         1                    toy story (1995)   animation|children's|comedy
# 1         2                      jumanji (1995)  adventure|children's|fantasy
# 2         3             grumpier old men (1995)                comedy|romance
# 3         4            waiting to exhale (1995)                  comedy|drama
# 4         5  father of the bride part ii (1995)                        comedy
# 5         6                         heat (1995)         action|crime|thriller
# 6         7                      sabrina (1995)                comedy|romance
# 7         8                 tom and huck (1995)          adventure|children's
# 8         9                 sudden death (1995)                        action
# 9        10                    goldeneye (1995)     action|adventure|thriller

# %%
movie_data = {v:k for k,v in zip(movies.movie_id,movies.title)}

# %% [markdown]
# # 분석
# - ratings에 있는 유니크한 영화 개수
# - ratings에 있는 유니크한 사용자 수
# - 가장 인기 있는 영화 30개(인기순)
#
# - 내가 선호하는 영화 5가지를 골라 ratings 추가
# - CSR matrix
# - als_model = AlternatingLeastSquares 모델
# - 내가 선호하는 5가지 영화 중 하나와 그 외의 영화 하나를 골라 훈련된 모델이 예측한 나의 선호도를 파악
# - 내가 좋아하는 영화와 비슷한 영화를 추천
# - 내가 가장 좋아할 만한 영화들을 추천

# %%
print("ratings에 있는 유니크한 영화 개수 : {}".format(ratings["movie_id"].nunique()))
print("ratings에 있는 유니크한 사용자 개수 : {}".format(ratings["user_id"].nunique()))
# Out:
# ratings에 있는 유니크한 영화 개수 : 3628
# ratings에 있는 유니크한 사용자 개수 : 6039

# %%
movie_count = ratings.groupby('movie_id')['user_id'].count()
top_30 = movie_count.sort_values(ascending=False).head(30)

# %%
def get_movie_titles(list_of_idx):
    movie_titles = [title for title,idx in movie_data.items() if idx in list_of_idx]
    return movie_titles

# %%
def idx_from_movies(list_of_movies):
    idxs = [idx for title,idx in movie_data.items() if title in list_of_movies]
    return idxs

# %%
def get_idx(movie_title):
    idx = movie_data[movie_title]
    return idx

# %%
get_movie_titles(top_30.index.tolist())
# Out:
# ['toy story (1995)',
#  'braveheart (1995)',
#  'star wars: episode iv - a new hope (1977)',
#  'pulp fiction (1994)',
#  'shawshank redemption, the (1994)',
#  'forrest gump (1994)',
#  'fugitive, the (1993)',
#  'jurassic park (1993)',
#  "schindler's list (1993)",
#  'terminator 2: judgment day (1991)',
#  'silence of the lambs, the (1991)',
#  'fargo (1996)',
#  'godfather, the (1972)',
#  'e.t. the extra-terrestrial (1982)',
#  'star wars: episode v - the empire strikes back (1980)',
#  'princess bride, the (1987)',
#  'raiders of the lost ark (1981)',
#  'star wars: episode vi - return of the jedi (1983)',
#  'terminator, the (1984)',
#  'groundhog day (1993)',
#  'back to the future (1985)',
#  'men in black (1997)',
#  'l.a. confidential (1997)',
#  'saving private ryan (1998)',
#  'shakespeare in love (1998)',
#  'matrix, the (1999)',
#  'ghostbusters (1984)',
#  'sixth sense, the (1999)',
#  'american beauty (1999)',
#  'being john malkovich (1999)']

# %%
pd.set_option('display.max_rows', None)

# %%
movies[movies['title'].str.contains('(2000)')]
# Out:
# /tmp/ipykernel_106/3360733546.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   movies[movies['title'].str.contains('(2000)')]
#       movie_id                                              title  \
# 1716      1772                         blues brothers 2000 (1998)
# 3090      3159                               fantasia 2000 (1999)
# 3121      3190                                   supernova (2000)
# 3156      3225                                 down to you (2000)
# 3170      3239                            isn't she great? (2000)
# 3204      3273                                    scream 3 (2000)
# 3207      3276                                     gun shy (2000)
# 3216      3285                                  beach, the (2000)
# 3217      3286                                    snow day (2000)
# 3218      3287                           tigger movie, the (2000)
# 3222      3291                                       trois (2000)
# 3229      3298                                 boiler room (2000)
# 3230      3299                                  hanging up (2000)
# 3231      3300                                 pitch black (2000)
# 3232      3301                       whole nine yards, the (2000)
# 3247      3316                              reindeer games (2000)
# 3248      3317                                 wonder boys (2000)
# 3252      3321                           waiting game, the (2000)
# 3253      3322                                   3 strikes (2000)
# 3254      3323                              chain of fools (2000)
# 3255      3324                               drowning mona (2000)
# 3256      3325                        next best thing, the (2000)
# 3257      3326                   what planet are you from? (2000)
# 3258      3327                              beyond the mat (2000)
# 3284      3353                         closer you get, the (2000)
# 3285      3354                             mission to mars (2000)
# 3286      3355                             ninth gate, the (2000)
# 3287      3356                              condo painting (2000)
# 3339      3408                             erin brockovich (2000)
# 3340      3409                           final destination (2000)
# 3383      3452                              romeo must die (2000)
# 3384      3453                               here on earth (2000)
# 3385      3454                           whatever it takes (2000)
# 3404      3473       jonah who will be 25 in the year 2000 (1976)
# 3412      3481                               high fidelity (2000)
# 3413      3482                              price of glory (2000)
# 3414      3483                      road to el dorado, the (2000)
# 3415      3484                                 skulls, the (2000)
# 3441      3510                                   frequency (2000)
# 3442      3511                             ready to rumble (2000)
# 3443      3512                                return to me (2000)
# 3444      3513                         rules of engagement (2000)
# 3445      3514                          joe gould's secret (2000)
# 3446      3515                                 me myself i (2000)
# 3465      3534                                     28 days (2000)
# 3466      3535                             american psycho (2000)
# 3467      3536                           keeping the faith (2000)
# 3468      3537                          where the money is (2000)
# 3810      3880                ballad of ramblin' jack, the (2000)
# 3811      3881                           bittersweet motel (2000)
# 3812      3882                                 bring it on (2000)
# 3813      3883                 catfish in black bean sauce (2000)
# 3814      3884                                   crew, the (2000)
# 3815      3885                                  love & sex (2000)
# 3816      3886                           steal this movie! (2000)
# 3818      3888                               skipped parts (2000)
# 3819      3889                         highlander: endgame (2000)
# 3820      3890                                  back stage (2000)
# 3821      3891                                  turn it up (2000)
# 3822      3892                          anatomy (anatomie) (2000)
# 3823      3893                                 nurse betty (2000)
# 3825      3895                                watcher, the (2000)
# 3826      3896                         way of the gun, the (2000)
# 3827      3897                               almost famous (2000)
# 3828      3898                                        bait (2000)
# 3829      3899                                      circus (2000)
# 3830      3900            crime and punishment in suburbia (2000)
# 3831      3901                                       duets (2000)
# 3833      3903                                     urbania (2000)
# 3834      3904                         uninvited guest, an (2000)
# 3835      3905                               specials, the (2000)
# 3836      3906                             under suspicion (2000)
# 3838      3908                    urban legends: final cut (2000)
# 3839      3909                                woman on top (2000)
# 3840      3910                          dancer in the dark (2000)
# 3841      3911                                best in show (2000)
# 3842      3912                                   beautiful (2000)
# 3844      3914                     broken hearts club, the (2000)
# 3845      3915                                   girlfight (2000)
# 3846      3916                         remember the titans (2000)
# 3873      3943                                  bamboozled (2000)
# 3874      3944                                     bootmen (2000)
# 3875      3945                          digimon: the movie (2000)
# 3876      3946                                  get carter (2000)
# 3878      3948                            meet the parents (2000)
# 3879      3949                         requiem for a dream (2000)
# 3880      3950                                   tigerland (2000)
# 3881      3951                            two family house (2000)
# 3882      3952                              contender, the (2000)
#
#                                genre
# 1716           action|comedy|musical
# 3090    animation|children's|musical
# 3121                adventure|sci-fi
# 3156                  comedy|romance
# 3170                          comedy
# 3204         horror|mystery|thriller
# 3207                          comedy
# 3216                 adventure|drama
# 3217                          comedy
# 3218            animation|children's
# 3222                        thriller
# 3229                           drama
# 3230                    comedy|drama
# 3231                   action|sci-fi
# 3232                    comedy|crime
# 3247                 action|thriller
# 3248                    comedy|drama
# 3252                          comedy
# 3253                          comedy
# 3254                    comedy|crime
# 3255                          comedy
# 3256                    comedy|drama
# 3257                   comedy|sci-fi
# 3258                     documentary
# 3284                  comedy|romance
# 3285                          sci-fi
# 3286                        thriller
# 3287                     documentary
# 3339                           drama
# 3340                  drama|thriller
# 3383                  action|romance
# 3384                   drama|romance
# 3385                  comedy|romance
# 3404                          comedy
# 3412                          comedy
# 3413                           drama
# 3414            animation|children's
# 3415                        thriller
# 3441                  drama|thriller
# 3442                          comedy
# 3443                   drama|romance
# 3444                  drama|thriller
# 3445                           drama
# 3446                          comedy
# 3465                          comedy
# 3466          comedy|horror|thriller
# 3467                  comedy|romance
# 3468                    comedy|drama
# 3470                     documentary
# 3484                  drama|thriller
# 3485                   drama|romance
# 3486                 action|thriller
# 3493                    comedy|drama
# 3494                   action|horror
# 3495               children's|comedy
# 3496                    comedy|drama
# 3497                    comedy|drama
# 3502                           drama
# 3509                    action|drama
# 3510                           drama
# 3511                           drama
# 3513                           drama
# 3524                   action|sci-fi
# 3525                           drama
# 3526                          comedy
# 3527                          comedy
# 3528                          comedy
# 3529                           drama
# 3546            animation|children's
# 3547                  comedy|romance
# 3548                          comedy
# 3549                          comedy
# 3554                 action|thriller
# 3555                          action
# 3577                          comedy
# 3578                           drama
# 3648                    action|crime
# 3650                  comedy|romance
# 3674                  comedy|romance
# 3675                    action|crime
# 3676      adventure|animation|sci-fi
# 3677                       drama|war
# 3681                           drama
# 3682     animation|children's|comedy
# 3683                          comedy
# 3684                action|drama|war
# 3685     animation|children's|comedy
# 3686       action|adventure|thriller
# 3687                           drama
# 3715                          comedy
# 3716                   comedy|horror
# 3721                           drama
# 3724                   action|sci-fi
# 3725                    comedy|drama
# 3727                romance|thriller
# 3728                        thriller
# 3729                        thriller
# 3730            animation|children's
# 3750                      children's
# 3751                          comedy
# 3754                   drama|romance
# 3755                           drama
# 3756          horror|sci-fi|thriller
# 3757                   action|sci-fi
# 3759                  comedy|romance
# 3760          comedy|horror|thriller
# 3761                          comedy
# 3781                          comedy
# 3782                          comedy
# 3787                        thriller
# 3788                          comedy
# 3789                     documentary
# 3791                          comedy
# 3792                          comedy
# 3793                 sci-fi|thriller
# 3794         action|adventure|sci-fi
# 3795              comedy|documentary
# 3796                          comedy
# 3809                          action
# 3810                     documentary
# 3811                     documentary
# 3812                          comedy
# 3813                    comedy|drama
# 3814                          comedy
# 3815                  comedy|romance
# 3816                           drama
# 3818                   drama|romance
# 3819        action|adventure|fantasy
# 3820                     documentary
# 3821                     crime|drama
# 3822                          horror
# 3823                 comedy|thriller
# 3825                  crime|thriller
# 3826                  crime|thriller
# 3827                    comedy|drama
# 3828                   action|comedy
# 3829                          comedy
# 3830                    comedy|drama
# 3831                    comedy|drama
# 3833                           drama
# 3834                           drama
# 3835                          comedy
# 3836                           crime
# 3838                          horror
# 3839                  comedy|romance
# 3840                   drama|musical
# 3841                          comedy
# 3842                    comedy|drama
# 3844                           drama
# 3845                           drama
# 3846                           drama
# 3873                          comedy
# 3874                    comedy|drama
# 3875  adventure|animation|children's
# 3876           action|drama|thriller
# 3878                          comedy
# 3879                           drama
# 3880                           drama
# 3881                           drama
# 3882                  drama|thriller

# %%
ratings['user_id'].unique()
# Out:
# array([   1,    2,    3, ..., 6038, 6039, 6040])

# %%
ratings.head()
# Out:
#    user_id  movie_id  ratings
# 0        1      1193        5
# 1        1       661        3
# 2        1       914        3
# 3        1      3408        4
# 4        1      2355        5

# %%
my_favorite = ['road to el dorado, the (2000)','mission: impossible 2 (2000)','me, myself and irene (2000)','x-men (2000)','digimon: the movie (2000)']

# %%
my_movie_list = pd.DataFrame({'user_id':[6041]*5, 'movie_id':idx_from_movies(my_favorite), 'ratings':[5]*5})

# %%
my_movie_list
# Out:
#    user_id  movie_id  ratings
# 0     6041      3483        5
# 1     6041      3623        5
# 2     6041      3752        5
# 3     6041      3793        5
# 4     6041      3945        5

# %%
ratings_new= pd.concat([ratings,my_movie_list]).reset_index(drop=True)
ratings_new.tail(10)
# Out:
#         user_id  movie_id  ratings
# 836473     6040      1090        3
# 836474     6040      1094        5
# 836475     6040       562        5
# 836476     6040      1096        4
# 836477     6040      1097        4
# 836478     6041      3483        5
# 836479     6041      3623        5
# 836480     6041      3752        5
# 836481     6041      3793        5
# 836482     6041      3945        5

# %%
ratings_new.head()
# Out:
#    user_id  movie_id  ratings
# 0        1      1193        5
# 1        1       661        3
# 2        1       914        3
# 3        1      3408        4
# 4        1      2355        5

# %%
# 고유한 유저, 아티스트를 찾아내는 코드
user_unique = ratings_new['user_id'].unique()
movie_unique = ratings_new['movie_id'].unique()

# 유저, 아티스트 indexing 하는 코드 idx는 index의 약자입니다.
user_to_idx = {v:k for k,v in enumerate(user_unique)}
artist_to_idx = {v:k for k,v in enumerate(movie_unique)}

# %%
temp_user_data = ratings_new['user_id'].map(user_to_idx.get).dropna()
if len(temp_user_data) == len(ratings_new):   # 모든 row가 정상적으로 인덱싱되었다면
    print('user_id column indexing OK!!')
    ratings_new['user_id'] = temp_user_data   # data['user_id']을 인덱싱된 Series로 교체해 줍니다. 
else:
    print('user_id column indexing Fail!!')
# Out:
# user_id column indexing OK!!

# %%
temp_movie_data = ratings_new['movie_id'].map(artist_to_idx.get).dropna()
if len(temp_movie_data ) == len(ratings_new):
    print('artist column indexing OK!!')
    ratings_new['movie_id'] = temp_movie_data 
else:
    print('artist column indexing Fail!!')
# Out:
# artist column indexing OK!!

# %%
ratings_new.head()
# Out:
#    user_id  movie_id  ratings
# 0        0         0        5
# 1        0         1        3
# 2        0         2        3
# 3        0         3        4
# 4        0         4        5

# %%
from scipy.sparse import csr_matrix

num_user = ratings_new['user_id'].nunique()
num_movies = ratings_new['movie_id'].nunique()

csr_data = csr_matrix((ratings_new['ratings'], (ratings_new['user_id'], ratings_new['movie_id'])), shape=(num_user, num_movies))

csr_data
# Out:
# <6040x3628 sparse matrix of type '<class 'numpy.int64'>'
# 	with 836483 stored elements in Compressed Sparse Row format>

# %%
from implicit.als import AlternatingLeastSquares
import os
import numpy as np

# implicit 라이브러리에서 권장하고 있는 부분입니다. 학습 내용과는 무관합니다.
os.environ['OPENBLAS_NUM_THREADS']='1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['MKL_NUM_THREADS']='1'

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=100, regularization=0.01, use_gpu=False, iterations=15, dtype=np.float32)

# %%
# als 모델은 input으로 (item X user 꼴의 matrix를 받기 때문에 Transpose해줍니다.)
csr_data_transpose = csr_data.T
csr_data_transpose
# Out:
# <3628x6040 sparse matrix of type '<class 'numpy.int64'>'
# 	with 836483 stored elements in Compressed Sparse Column format>

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
idx_from_movies(['road to el dorado, the (2000)'])
# Out:
# [3483]

# %%
me, eldorado = user_to_idx[6041], artist_to_idx[get_idx('road to el dorado, the (2000)')]
me_vector, eldorado_vector = als_model.user_factors[me], als_model.item_factors[eldorado]

# %%
me_vector
# Out:
# array([ 2.3460896e-01,  1.1041111e+00,  8.2746577e-01,  5.2757627e-01,
#        -4.6262321e-01, -1.4321464e+00, -2.9302028e-01,  2.2658376e-01,
#         1.05655724e-02,  2.18569580e-03,  5.79496473e-03,  1.85799180e-03,
#         2.71318504e-03, -7.66322436e-03, -9.62828565e-03, -1.39925617e-03,
#        -3.18664219e-03, -4.81473841e-03, -7.56185222e-03, -1.00183999e-02,
#         1.56955887e-02,  8.26248154e-03,  7.65951932e-04,  8.17046035e-04,
#        -1.50199812e-02,  6.06406899e-03, -5.79417590e-03,  7.61841144e-03,
#         2.72301189e-03, -1.04794384e-03,  7.77921639e-03,  8.97350349e-03,
#        -4.32277238e-03,  5.81357861e-03,  1.04173804e-02, -6.30828086e-03,
#         9.86190513e-04,  1.48942536e-02,  1.41814742e-02, -1.55627716e-03,
#        -1.87037408e-03,  1.66656859e-02, -5.33645460e-03,  2.39370216e-04,
#         4.56886040e-03,  5.56180021e-03, -5.08436980e-03, -5.43468585e-03,
#         9.52788536e-03, -3.22577660e-03,  6.25746371e-03,  4.51246370e-03,
#         1.30133303e-02,  8.40624887e-03, -6.43176865e-03,  1.04945460e-02,
#         1.15726679e-03,  1.03081027e-02, -2.53293925e-04,  1.70614826e-03,
#         1.44615397e-02,  1.36263045e-02,  8.86255130e-03,  3.58304963e-03],
#       dtype=float32)

# %%
np.dot(me_vector, eldorado_vector)
# Out:
# 0.16739385

# %%
queen = artist_to_idx[get_idx('mission: impossible 2 (2000)')]
queen_vector = als_model.item_factors[queen]
np.dot(me_vector, queen_vector)
# Out:
# 0.6080707

# %%
artist_id = artist_to_idx[get_idx('mission: impossible 2 (2000)')]
similar_artist = als_model.similar_items(artist_id, N=15)
similar_artist
# Out:
# [(482, 0.9999999),
#  (327, 0.6472007),
#  (67, 0.5746914),
#  (903, 0.5503333),
#  (1737, 0.53150445),
#  (346, 0.5165638),
#  (1537, 0.5047207),
#  (633, 0.5027408),
#  (463, 0.48598206),
#  (792, 0.46748605),
#  (372, 0.4673728),
#  (746, 0.45676163),
#  (782, 0.45395672),
#  (1858, 0.43929908),
#  (1031, 0.43451598)]

# %%
def get_similar_artist(movie_name: str):
    artist_id = artist_to_idx[get_idx(movie_name)]
    similar_artist = als_model.similar_items(artist_id)
    similar_artist = [idx_to_artist[i[0]] for i in similar_artist]
    return similar_artist

# %%
get_similar_artist('mission: impossible 2 (2000)')
# Out:
# [3623, 3717, 3578, 3744, 3452, 3753, 3555, 3593, 3510, 3798]

# %%
get_movie_titles(get_similar_artist('mission: impossible 2 (2000)'))
# Out:
# ['romeo must die (2000)',
#  'frequency (2000)',
#  'u-571 (2000)',
#  'gladiator (2000)',
#  'battlefield earth (2000)',
#  'mission: impossible 2 (2000)',
#  'gone in 60 seconds (2000)',
#  'shaft (2000)',
#  'patriot, the (2000)',
#  'what lies beneath (2000)']

# %%
user = user_to_idx[6041]
artist_recommended = als_model.recommend(user, csr_data, N=20, filter_already_liked_items=True)

# %%
artist_recommended
rec = get_movie_titles([idx_to_artist[i[0]] for i in artist_recommended])
rec
# Out:
# ['sleepy hollow (1999)',
#  'scream 3 (2000)',
#  'pitch black (2000)',
#  'romeo must die (2000)',
#  'frequency (2000)',
#  'gladiator (2000)',
#  'dinosaur (2000)',
#  'road trip (2000)',
#  'shanghai noon (2000)',
#  'gone in 60 seconds (2000)',
#  'shaft (2000)',
#  'titan a.e. (2000)',
#  'chicken run (2000)',
#  'patriot, the (2000)',
#  'perfect storm, the (2000)',
#  'scary movie (2000)',
#  'what lies beneath (2000)',
#  'nutty professor ii: the klumps (2000)',
#  'space cowboys (2000)',
#  'cell, the (2000)']

# %%
rihanna = artist_to_idx[get_idx('scream 3 (2000)')]
explain = als_model.explain(user, csr_data, itemid=rihanna)

# %%
a = [(idx_to_artist[i[0]], i[1]) for i in explain[1]]
a
# Out:
# [(3752, 0.09008038870950245),
#  (3623, 0.0789718829683423),
#  (3793, 0.057724011239917654),
#  (3483, 0.012569774012179215),
#  (3945, 0.0009584823632744399)]

# %%
get_movie_titles([i[0] for i in a ])
# Out:
# ['road to el dorado, the (2000)',
#  'mission: impossible 2 (2000)',
#  'me, myself and irene (2000)',
#  'x-men (2000)',
#  'digimon: the movie (2000)']

# %%
for i in rec :
    print(i, movies[movies['title']==i].genre)
# Out:
# sleepy hollow (1999) 3012    horror|romance
# Name: genre, dtype: object
# scream 3 (2000) 3204    horror|mystery|thriller
# Name: genre, dtype: object
# pitch black (2000) 3231    action|sci-fi
# Name: genre, dtype: object
# romeo must die (2000) 3383    action|romance
# Name: genre, dtype: object
# frequency (2000) 3441    drama|thriller
# Name: genre, dtype: object
# gladiator (2000) 3509    action|drama
# Name: genre, dtype: object
# dinosaur (2000) 3546    animation|children's
# Name: genre, dtype: object
# road trip (2000) 3548    comedy
# Name: genre, dtype: object
# shanghai noon (2000) 3555    action
# Name: genre, dtype: object
# gone in 60 seconds (2000) 3648    action|crime
# Name: genre, dtype: object
# shaft (2000) 3675    action|crime
# Name: genre, dtype: object
# titan a.e. (2000) 3676    adventure|animation|sci-fi
# Name: genre, dtype: object
# chicken run (2000) 3682    animation|children's|comedy
# Name: genre, dtype: object
# patriot, the (2000) 3684    action|drama|war
# Name: genre, dtype: object
# perfect storm, the (2000) 3686    action|adventure|thriller
# Name: genre, dtype: object
# scary movie (2000) 3716    comedy|horror
# Name: genre, dtype: object
# what lies beneath (2000) 3729    thriller
# Name: genre, dtype: object
# nutty professor ii: the klumps (2000) 3751    comedy
# Name: genre, dtype: object
# space cowboys (2000) 3757    action|sci-fi
# Name: genre, dtype: object
# cell, the (2000) 3793    sci-fi|thriller
# Name: genre, dtype: object

# %% [markdown]
# # 회고
# 추천해준 것들을 보았을 때, 가장 큰 특징은 전부 2000년도에 분포되어있는 영화라는 것이다. 하지만, 내가 좋아하는 몇몇의 영화가 있는 것으로 보아 어느정도 추천을 잘 해주었다고 생각을 한다.
